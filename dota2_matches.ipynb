# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Commit changes to github #

# %%
# https://towardsdatascience.com/google-drive-google-colab-github-dont-just-read-do-it-5554d5824228
# Mount Google Drive
from google.colab import drive # import drive from google colab

ROOT = "/content/drive"     # default location for the drive
print(ROOT)                 # print content of ROOT (Optional)

drive.mount(ROOT)           # we mount the google drive at /content/drive
# Out:
# /content/drive
# Mounted at /content/drive

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd 'drive/My Drive/machine_learning/cs498-dota2-matches/cs498-dota2-matches'
# Out:
# /content/drive/My Drive/machine_learning/cs498-dota2-matches/cs498-dota2-matches

# %%
#Check the status of the files that changed
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	archive/
# 	dota2_matches.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
#Add tracked files
# !git add .
# Out:
# ^C

# %%
#Commit the changes
# !git commit -m "add dota2_matches.ipynb"
